# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %% [markdown]
# # 대중교통 환승 편의성 지표 (2023)

# %%
df1 = pd.read_excel('/content/drive/MyDrive/BDA/data/교통 인프라 지표 데이터 (지원)/대중교통 환승 편의성 지표.xlsx')

# %%
print(len(df1))
df1.head()
# Out:
# 248
#   SIGNGU_CD  TKCAR_TRFC_QTY  AVE_TRAF_NMTM  AVE_TRAF_WAIT_TM  \
# 0     11110       144511783        33.9772           45293.0
# 1     11140       189906959        13.7726           23669.0
# 2     11170        85613402        26.5910           36689.0
# 3     11200        90398714        22.8651           36417.0
# 4     11215        90052173        20.1311           34806.0
#
#    PBTS_TRAF_TRFC_RATE
# 0               8.4746
# 1               7.0540
# 2              11.6868
# 3               9.5599
# 4               9.5304

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248 entries, 0 to 247
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   SIGNGU_CD            248 non-null    object
#  1   TKCAR_TRFC_QTY       248 non-null    int64
#  2   AVE_TRAF_NMTM        248 non-null    float64
#  3   AVE_TRAF_WAIT_TM     222 non-null    float64
#  4   PBTS_TRAF_TRFC_RATE  248 non-null    float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 9.8+ KB

# %%
df1.drop([246, 247], axis=0, inplace=True)

# %%
df1['SIGNGU_CD'].value_counts()
# Out:
# SIGNGU_CD
# 11110    1
# 11140    1
# 11170    1
# 11200    1
# 11215    1
#         ..
# 51790    1
# 51800    1
# 51810    1
# 51820    1
# 51830    1
# Name: count, Length: 246, dtype: int64

# %%
df1
# Out:
#     SIGNGU_CD  TKCAR_TRFC_QTY  AVE_TRAF_NMTM  AVE_TRAF_WAIT_TM  \
# 0       11110       144511783        33.9772           45293.0
# 1       11140       189906959        13.7726           23669.0
# 2       11170        85613402        26.5910           36689.0
# 3       11200        90398714        22.8651           36417.0
# 4       11215        90052173        20.1311           34806.0
# ..        ...             ...            ...               ...
# 241     51790          150762         2.2631            7825.0
# 242     51800              26         0.4507               NaN
# 243     51810          218768        15.8473           86203.0
# 244     51820          591058        38.7869          157822.0
# 245     51830          432316         0.0715            2041.0
#
#      PBTS_TRAF_TRFC_RATE
# 0                 8.4746
# 1                 7.0540
# 2                11.6868
# 3                 9.5599
# 4                 9.5304
# ..                   ...
# ...

# %%
평균환승횟수 = df1.loc[:, ['SIGNGU_CD', 'AVE_TRAF_NMTM']]
평균환승대기시간 = df1.loc[:, ['SIGNGU_CD', 'AVE_TRAF_WAIT_TM']]
대중교통환승통행비율 = df1.loc[:, ['SIGNGU_CD', 'PBTS_TRAF_TRFC_RATE']]

# %%
평균환승횟수.to_csv('평균환승횟수 전처리.csv',index=False)
평균환승대기시간.to_csv('평균환승대기시간 전처리.csv',index=False)
대중교통환승통행비율.to_csv('대중교통환승통행비율 전처리.csv',index=False)

from google.colab import files
files.download('평균환승횟수 전처리.csv')
files.download('평균환승대기시간 전처리.csv')
files.download('대중교통환승통행비율 전처리.csv')

# %%
df1.to_csv('대중교통 환승 편의성 지표 전처리.csv',index=False)

from google.colab import files
files.download('대중교통 환승 편의성 지표 전처리.csv')

# %% [markdown]
# # 교통 접근성 지표 - 평균접근시간 (2022)

# %%
df2 = pd.read_excel('/content/drive/MyDrive/BDA/data/교통 인프라 지표 데이터 (지원)/교통접근성지표/평균접근시간_2022.xlsx')

# %%
df2.head()
# Out:
#      Year        HDCD  Faci_CD HDCD_SD_NM HDCD_SGG_NM Faci_NM  평균접근시간(분)
# 0  2022.0        11.0     41.0      서울특별시           -   버스터미널  37.565549
# 1  2022.0        11.0     42.0      서울특별시           -     철도역  28.683642
# 2  2022.0      1101.0     41.0      서울특별시         종로구   버스터미널  43.267841
# 3  2022.0      1101.0     42.0      서울특별시         종로구     철도역  24.657437
# 4  2022.0  11010530.0     41.0      서울특별시         종로구   버스터미널  39.973400

# %% [markdown]
# 작성된 시군구에 맞지않는 지역코드가 입력되어있음 -> 수정 과정 필요

# %%
df2['HDCD_NM'] = df2['HDCD_SD_NM'] + ' ' + df2['HDCD_SGG_NM']
df2.drop(columns=['HDCD_SD_NM','HDCD_SGG_NM'], axis=1, inplace=True)

# %%
# 법정동 시군구 코드 데이터 불러오기
standard_codes = pd.read_csv('/content/drive/MyDrive/BDA/data/0 인프라지수 최종 종합/국민여행조사_지역코드.csv')

df2 = df2.merge(
    standard_codes,
    how='left',
    left_on=['HDCD_NM'],
    right_on=['지역명 ']
    )

# 기존 HDCD 컬럼을 새 코드로 대체
df2['HDCD'] = df2['지역 코드']

# 시군구코드 5자리만 남기고 나머지 제거
df2['HDCD'] = df2['HDCD'].astype(str).str[:5]

# 불필요한 컬럼 삭제
df2.drop(columns=['지역명 ', '지역 코드'], axis=1, inplace=True)
df2.dropna(axis=0, inplace=True)

# %%
df2.head()
# Out:
#      Year   HDCD  Faci_CD Faci_NM  평균접근시간(분)    HDCD_NM
# 0  2022.0    nan     41.0   버스터미널  37.565549    서울특별시 -
# 1  2022.0    nan     42.0     철도역  28.683642    서울특별시 -
# 2  2022.0  11010     41.0   버스터미널  43.267841  서울특별시 종로구
# 3  2022.0  11010     42.0     철도역  24.657437  서울특별시 종로구
# 4  2022.0  11010     41.0   버스터미널  39.973400  서울특별시 종로구

# %%
nan_index = df2[df2['HDCD']=='nan'].index
df2.loc[nan_index, 'HDCD_NM'].value_counts()
# Out:
# HDCD_NM
# 세종특별자치시 세종시       50
# 경기도 성남시 분당구       46
# 인천광역시 미추홀구        44
# 경기도 고양시 덕양구       44
# 충청남도 천안시 동남구      40
# 전라북도 전주시 완산구      40
# 경기도 성남시 수정구       36
# 경기도 안양시 동안구       36
# 경상북도 포항시 북구       36
# 경상남도 창원시 마산합포구    36
# 전라북도 전주시 덕진구      34
# 경상북도 포항시 남구       34
# 충청남도 천안시 서북구      34
# 경기도 용인시 기흥구       32
# 충청북도 청주시 상당구      32
# 경상남도 창원시 마산회원구    30
# 경기도 안양시 만안구       30
# 경기도 용인시 처인구       30
# 경기도 안산시 상록구       28
# 경상남도 창원시 진해구      28
# 충청북도 청주시 흥덕구      28
# 충청북도 청주시 서원구      28
# 경기도 안산시 단원구       26
# 경기도 수원시 권선구       26
# 경기도 수원시 영통구       26
# 경기도 고양시 일산동구      26
# 경기도 고양시 일산서구      24
# 경기도 용인시 수지구       24
# 경기도 성남시 중원구       24
# 경기도 수원시 팔달구       22
# 경기도 수원시 장안구       22
# 충청북도 청주시 청원구      22
# 경상남도 창원시 의창구      20
# 경상남도 창원시 성산구      18
# 부산광역시 -            6
# 충청남도 -             6
# 충청북도 -             6
# 강원도 -              6
# 세종특별자치시 -          6
# 울산광역시 -            6
# 인천광역시 -            6
# 대구광역시 -            6
# 경기도 -              6
# ...

# %%
df2.loc[nan_index, 'HDCD_NM'] = df2.loc[nan_index, 'HDCD_NM'].apply(lambda x: " ".join(x.split()[:-1]))

# %%
standard_codes = pd.read_csv('/content/drive/MyDrive/BDA/data/0 인프라지수 최종 종합/국민여행조사_지역코드.csv')

df2 = df2.merge(
    standard_codes,
    how='left',
    left_on=['HDCD_NM'],
    right_on=['지역명 ']
    )

# 기존 HDCD 컬럼을 새 코드로 대체
df2['HDCD'] = df2['지역 코드']

# 시군구코드 5자리만 남기고 나머지 제거
df2['HDCD'] = df2['HDCD'].astype(str).str[:5]

# 불필요한 컬럼 삭제
df2.drop(columns=['지역명 ', '지역 코드'], axis=1, inplace=True)
df2.dropna(axis=0, inplace=True)

# %%
nan_index = df2[df2['HDCD']=='nan'].index
df2.loc[nan_index, 'HDCD_NM'].value_counts()
# Out:
# HDCD_NM
# 인천광역시      50
# 부산광역시       6
# 대구광역시       6
# 경기도         6
# 울산광역시       6
# 충청남도        6
# 충청북도        6
# 강원도         6
# 전라남도        6
# 경상북도        6
# 경상남도        6
# 전라북도        6
# 제주특별자치도     6
# 광주광역시       2
# 서울특별시       2
# 대전광역시       2
# Name: count, dtype: int64

# %% [markdown]
# 필요없는 변수 제거

# %%
df2.drop(columns=['Year', 'Faci_CD', 'Faci_NM', 'HDCD_NM'], axis=1, inplace=True)
df2.drop(nan_index, axis=0, inplace=True)

# %%
df2.to_csv('평균접근시간 전처리.csv',index=False)

from google.colab import files
files.download('평균접근시간 전처리.csv')

# %% [markdown]
# # 교통 접근성 지표 - 평균접근가능시설수 (2022)

# %%
df3 = pd.read_excel('/content/drive/MyDrive/BDA/data/교통 인프라 지표 데이터 (지원)/교통접근성지표/평균접근시간_2022.xlsx')

# %%
df3.head()
# Out:
#      Year        HDCD  Faci_CD HDCD_SD_NM HDCD_SGG_NM Faci_NM  평균접근시간(분)
# 0  2022.0        11.0     41.0      서울특별시           -   버스터미널  37.565549
# 1  2022.0        11.0     42.0      서울특별시           -     철도역  28.683642
# 2  2022.0      1101.0     41.0      서울특별시         종로구   버스터미널  43.267841
# 3  2022.0      1101.0     42.0      서울특별시         종로구     철도역  24.657437
# 4  2022.0  11010530.0     41.0      서울특별시         종로구   버스터미널  39.973400

# %%
df3['HDCD_NM'] = df3['HDCD_SD_NM'] + ' ' + df3['HDCD_SGG_NM']
df3.drop(columns=['HDCD_SD_NM','HDCD_SGG_NM'], axis=1, inplace=True)

# %%
# 법정동 시군구 코드 데이터 불러오기
standard_codes = pd.read_csv('/content/drive/MyDrive/BDA/data/0 인프라지수 최종 종합/국민여행조사_지역코드.csv')

df3 = df3.merge(
    standard_codes,
    how='left',
    left_on=['HDCD_NM'],
    right_on=['지역명 ']
    )

# 기존 HDCD 컬럼을 새 코드로 대체
df3['HDCD'] = df3['지역 코드']

# 시군구코드 5자리만 남기고 나머지 제거
df3['HDCD'] = df3['HDCD'].astype(str).str[:5]

# 불필요한 컬럼 삭제
df3.drop(columns=['지역명 ', '지역 코드'], axis=1, inplace=True)
df3.dropna(axis=0, inplace=True)

# %%
df3.head()
# Out:
#      Year   HDCD  Faci_CD Faci_NM  평균접근시간(분)    HDCD_NM
# 0  2022.0    nan     41.0   버스터미널  37.565549    서울특별시 -
# 1  2022.0    nan     42.0     철도역  28.683642    서울특별시 -
# 2  2022.0  11010     41.0   버스터미널  43.267841  서울특별시 종로구
# 3  2022.0  11010     42.0     철도역  24.657437  서울특별시 종로구
# 4  2022.0  11010     41.0   버스터미널  39.973400  서울특별시 종로구

# %%
nan_index = df3[df3['HDCD']=='nan'].index
df3.loc[nan_index, 'HDCD_NM'].value_counts()
# Out:
# HDCD_NM
# 세종특별자치시 세종시       50
# 경기도 성남시 분당구       46
# 인천광역시 미추홀구        44
# 경기도 고양시 덕양구       44
# 충청남도 천안시 동남구      40
# 전라북도 전주시 완산구      40
# 경기도 성남시 수정구       36
# 경기도 안양시 동안구       36
# 경상북도 포항시 북구       36
# 경상남도 창원시 마산합포구    36
# 전라북도 전주시 덕진구      34
# 경상북도 포항시 남구       34
# 충청남도 천안시 서북구      34
# 경기도 용인시 기흥구       32
# 충청북도 청주시 상당구      32
# 경상남도 창원시 마산회원구    30
# 경기도 안양시 만안구       30
# 경기도 용인시 처인구       30
# 경기도 안산시 상록구       28
# 경상남도 창원시 진해구      28
# 충청북도 청주시 흥덕구      28
# 충청북도 청주시 서원구      28
# 경기도 안산시 단원구       26
# 경기도 수원시 권선구       26
# 경기도 수원시 영통구       26
# 경기도 고양시 일산동구      26
# 경기도 고양시 일산서구      24
# 경기도 용인시 수지구       24
# 경기도 성남시 중원구       24
# 경기도 수원시 팔달구       22
# 경기도 수원시 장안구       22
# 충청북도 청주시 청원구      22
# 경상남도 창원시 의창구      20
# 경상남도 창원시 성산구      18
# 부산광역시 -            6
# 충청남도 -             6
# 충청북도 -             6
# 강원도 -              6
# 세종특별자치시 -          6
# 울산광역시 -            6
# 인천광역시 -            6
# 대구광역시 -            6
# 경기도 -              6
# ...

# %%
df3.loc[nan_index, 'HDCD_NM'] = df3.loc[nan_index, 'HDCD_NM'].apply(lambda x: " ".join(x.split()[:-1]))

# %%
standard_codes = pd.read_csv('/content/drive/MyDrive/BDA/data/0 인프라지수 최종 종합/국민여행조사_지역코드.csv')

df3 = df3.merge(
    standard_codes,
    how='left',
    left_on=['HDCD_NM'],
    right_on=['지역명 ']
    )

# 기존 HDCD 컬럼을 새 코드로 대체
df3['HDCD'] = df3['지역 코드']

# 시군구코드 5자리만 남기고 나머지 제거
df3['HDCD'] = df3['HDCD'].astype(str).str[:5]

# 불필요한 컬럼 삭제
df3.drop(columns=['지역명 ', '지역 코드'], axis=1, inplace=True)
df3.dropna(axis=0, inplace=True)

# %%
nan_index = df3[df3['HDCD']=='nan'].index
df3.loc[nan_index, 'HDCD_NM'].value_counts()
# Out:
# HDCD_NM
# 인천광역시      50
# 부산광역시       6
# 대구광역시       6
# 경기도         6
# 울산광역시       6
# 충청남도        6
# 충청북도        6
# 강원도         6
# 전라남도        6
# 경상북도        6
# 경상남도        6
# 전라북도        6
# 제주특별자치도     6
# 광주광역시       2
# 서울특별시       2
# 대전광역시       2
# Name: count, dtype: int64

# %% [markdown]
# 필요없는 변수 제거

# %%
df3.drop(columns=['Year', 'Faci_CD', 'Faci_NM', 'HDCD_NM'], axis=1, inplace=True)
df3.drop(nan_index, axis=0, inplace=True)

# %%
df3.to_csv('접근가능시설수 전처리.csv',index=False)

from google.colab import files
files.download('접근가능시설수 전처리.csv')

# %% [markdown]
# # 평균통행거리

# %% [markdown]
# ## (2024)

# %%
df4 = pd.read_excel('/content/drive/MyDrive/BDA/data/교통 인프라 지표 데이터 (지원)/평균 통행거리/통행시간·거리 지표(평균통행거리)_2024.xlsx')

# %%
df4.head()
# Out:
#    시도코드     시도  시군구     년     합계
# 0    11  서울특별시  강남구  2024  12.29
# 1     0      0  강동구  2024  10.14
# 2     0      0  강북구  2024   8.50
# 3     0      0  강서구  2024  11.29
# 4     0      0  관악구  2024   9.19

# %% [markdown]
# 시군구코드가 명시되어있지않음

# %%
code_index = df4[df4['시도'] != 0].index

# %%
code_index
# Out:
# Index([0, 25, 41, 50, 60, 65, 70, 75, 76, 107, 117, 132, 146, 167, 188, 206,
#        208, 226],
#       dtype='int64')

# %%
df4.loc[code_index, '시도']
# Out:
# 0        서울특별시
# 25       부산광역시
# 41       대구광역시
# 50       인천광역시
# 60       광주광역시
# 65       대전광역시
# 70       울산광역시
# 75     세종특별자치시
# 76         경기도
# 107       충청북도
# 117       충청남도
# 132       전라북도
# 146       전라남도
# 167       경상북도
# 188       경상남도
# 206    제주특별자치도
# 208    강원특별자치도
# 226    전북특별자치도
# Name: 시도, dtype: object

# %%
for i in range(len(code_index)-1):
    start = code_index[i]
    end = code_index[i+1]
    df4.loc[start:end-1,'시도'] = df4.loc[start,'시도']

df4.loc[code_index[-1]:,'시도'] = df4.loc[code_index[-1],'시도']

# %%
df4
# Out:
#      시도코드       시도  시군구     년     합계
# 0      11    서울특별시  강남구  2024  12.29
# 1       0    서울특별시  강동구  2024  10.14
# 2       0    서울특별시  강북구  2024   8.50
# 3       0    서울특별시  강서구  2024  11.29
# 4       0    서울특별시  관악구  2024   9.19
# ..    ...      ...  ...   ...    ...
# 235     0  전북특별자치도  임실군  2024  22.47
# 236     0  전북특별자치도  장수군  2024  28.43
# 237     0  전북특별자치도  전주시  2024  10.33
# 238     0  전북특별자치도  정읍시  2024  21.20
# 239     0  전북특별자치도  진안군  2024   0.00
#
# [240 rows x 5 columns]

# %%
df4['시군구명'] = df4['시도'].astype(str) + ' ' + df4['시군구'].astype(str)
df4.drop(columns=['시도','시군구'], axis=1, inplace=True)

# %%
standard_codes = pd.read_csv('/content/drive/MyDrive/BDA/data/0 인프라지수 최종 종합/국민여행조사_지역코드.csv')

df4 = df4.merge(
    standard_codes,
    how='left',
    left_on=['시군구명'],
    right_on=['지역명 ']
    )

# 기존 시도코드 컬럼을 새 코드로 대체
df4['시도코드'] = df4['지역 코드']

# 시군구코드 5자리만 남기고 나머지 제거
df4['시도코드'] = df4['시도코드'].astype(str).str[:5]

# 불필요한 컬럼 삭제
df4.drop(columns=['지역명 ', '지역 코드'], axis=1, inplace=True)
df4.dropna(axis=0, inplace=True)

# %%
nan_index = df4[df4['시도코드']=='nan'].index
nan_index
# Out:
# Index([ 41,  54,  75, 208, 209, 210, 211, 212, 213, 214, 215, 216, 217, 218,
#        219, 220, 221, 222, 223, 224, 225, 226, 227, 228, 229, 230, 231, 232,
#        233, 234, 235, 236, 237, 238, 239],
#       dtype='int64')

# %%
nan_index = df4[df4['시도코드']=='nan'].index
df4.loc[nan_index, '시군구명'].value_counts()
# Out:
# 시군구명
# 대구광역시 군위군      1
# 인천광역시 미추홀구     1
# 세종특별자치시 세종시    1
# 강원특별자치도 강릉시    1
# 강원특별자치도 고성군    1
# 강원특별자치도 동해시    1
# 강원특별자치도 삼척시    1
# 강원특별자치도 속초시    1
# 강원특별자치도 양구군    1
# 강원특별자치도 양양군    1
# 강원특별자치도 영월군    1
# 강원특별자치도 원주시    1
# 강원특별자치도 인제군    1
# 강원특별자치도 정선군    1
# 강원특별자치도 철원군    1
# 강원특별자치도 춘천시    1
# 강원특별자치도 태백시    1
# 강원특별자치도 평창군    1
# 강원특별자치도 홍천군    1
# 강원특별자치도 화천군    1
# 강원특별자치도 횡성군    1
# 전북특별자치도 고창군    1
# 전북특별자치도 군산시    1
# 전북특별자치도 김제시    1
# 전북특별자치도 남원시    1
# 전북특별자치도 무주군    1
# 전북특별자치도 부안군    1
# 전북특별자치도 순창군    1
# 전북특별자치도 완주군    1
# 전북특별자치도 익산시    1
# 전북특별자치도 임실군    1
# 전북특별자치도 장수군    1
# 전북특별자치도 전주시    1
# 전북특별자치도 정읍시    1
# 전북특별자치도 진안군    1
# Name: count, dtype: int64

# %%
# 강원특별자치도 -> 강원도 변경, 전북특별자치도 -> 전라북도 변경
def replace_special_province(address):
    if isinstance(address, str):
        if address.startswith("강원특별자치도"):
            return address.replace("강원특별자치도", "강원도")
        elif address.startswith("전북특별자치도"):
            return address.replace("전북특별자치도", "전라북도")
    return address

df4.loc[nan_index, '시군구명'] = df4.loc[nan_index, '시군구명'].apply(replace_special_province)

# 세종특별자치시 세종시 -> 세종특별자치시
df4.loc[nan_index[2], '시군구명'] = " ".join(df4.loc[2, '시군구명'].split()[:-1])

# 대구광역시 군위군, 인천광역시 미추홀구 -> 국민여행조사 코드북에 코드가 X
df4.drop(nan_index[[0,1]], axis=0, inplace=True)

# %%
nan_index = df4[df4['시도코드']=='nan'].index
df4.loc[nan_index, '시군구명'].value_counts()
# Out:
# 시군구명
# 서울특별시       1
# 강원도 강릉시     1
# 강원도 고성군     1
# 강원도 동해시     1
# 강원도 삼척시     1
# 강원도 속초시     1
# 강원도 양구군     1
# 강원도 양양군     1
# 강원도 영월군     1
# 강원도 원주시     1
# 강원도 인제군     1
# 강원도 정선군     1
# 강원도 철원군     1
# 강원도 춘천시     1
# 강원도 태백시     1
# 강원도 평창군     1
# 강원도 홍천군     1
# 강원도 화천군     1
# 강원도 횡성군     1
# 전라북도 고창군    1
# 전라북도 군산시    1
# 전라북도 김제시    1
# 전라북도 남원시    1
# 전라북도 무주군    1
# 전라북도 부안군    1
# 전라북도 순창군    1
# 전라북도 완주군    1
# 전라북도 익산시    1
# 전라북도 임실군    1
# 전라북도 장수군    1
# 전라북도 전주시    1
# 전라북도 정읍시    1
# 전라북도 진안군    1
# Name: count, dtype: int64

# %%
standard_codes = pd.read_csv('/content/drive/MyDrive/BDA/data/0 인프라지수 최종 종합/국민여행조사_지역코드.csv')

df4 = df4.merge(
    standard_codes,
    how='left',
    left_on=['시군구명'],
    right_on=['지역명 ']
    )

# 기존 시도코드 컬럼을 새 코드로 대체
df4['시도코드'] = df4['지역 코드']

# 시군구코드 5자리만 남기고 나머지 제거
df4['시도코드'] = df4['시도코드'].astype(str).str[:5]

# 불필요한 컬럼 삭제
df4.drop(columns=['지역명 ', '지역 코드'], axis=1, inplace=True)
df4.dropna(axis=0, inplace=True)

# %%
df4.drop(columns=['년','시군구명'], axis=1, inplace=True)

# %%
df4
# Out:
#       시도코드     합계
# 0    11230  12.29
# 1    11250  10.14
# 2    11090   8.50
# 3    11160  11.29
# 4    11210   9.19
# ..     ...    ...
# 233  35350  22.47
# 234  35340  28.43
# 235  35010  10.33
# 236  35040  21.20
# 237  35320   0.00
#
# [238 rows x 2 columns]

# %%
df4[df4['시도코드']=='nan'].count()
# Out:
# 시도코드    0
# 합계      0
# dtype: int64

# %%
nan_index = df4[df4['시도코드']=='nan'].index
df4.drop(nan_index, axis=0, inplace=True)

# %%
df4.to_csv('평균통행거리_2024_전처리.csv',index=False)

from google.colab import files
files.download('평균통행거리_2024_전처리.csv')

# %% [markdown]
# # 이용량 지표(환승통행량)

# %% [markdown]
# ## (2024)

# %%
df7 = pd.read_excel('/content/drive/MyDrive/BDA/data/교통 인프라 지표 데이터 (지원)/이용량 지표(환승 통행량)/이용량 지표(환승통행량)_2024.xlsx')

# %%
df7.head()
# Out:
#   시도코드     시도  시군구     년         발생량         도착량
# 0   합계      0    0     0  1660709916  1499452237
# 1   11  서울특별시  강남구  2024    60502130    84156330
# 2    0      0  강동구  2024    17546120    15628516
# 3    0      0  강북구  2024    27285437    20790579
# 4    0      0  강서구  2024    32728567    29761796

# %%
df7.drop(0, axis=0, inplace=True)

# %% [markdown]
# 시군구코드가 명시되어있지않음

# %%
code_index = df7[df7['시도'] != 0].index

# %%
code_index
# Out:
# Index([1, 26, 42, 51, 61, 66, 71, 76, 77, 108, 117, 132, 142, 157, 175, 189,
#        191, 208],
#       dtype='int64')

# %%
df7.loc[code_index, '시도']
# Out:
# 1        서울특별시
# 26       부산광역시
# 42       대구광역시
# 51       인천광역시
# 61       광주광역시
# 66       대전광역시
# 71       울산광역시
# 76     세종특별자치시
# 77         경기도
# 108       충청북도
# 117       충청남도
# 132       전라북도
# 142       전라남도
# 157       경상북도
# 175       경상남도
# 189    제주특별자치도
# 191    강원특별자치도
# 208    전북특별자치도
# Name: 시도, dtype: object

# %%
len(code_index)
# Out:
# 18

# %%
for i in range(len(code_index)-1):
    start = code_index[i]
    end = code_index[i+1]
    df7.loc[start:end-1,'시도'] = df7.loc[start,'시도']

df7.loc[code_index[-1]:,'시도'] = df7.loc[code_index[-1],'시도']

# %%
df7
# Out:
#     시도코드       시도  시군구     년       발생량       도착량
# 1     11    서울특별시  강남구  2024  60502130  84156330
# 2      0    서울특별시  강동구  2024  17546120  15628516
# 3      0    서울특별시  강북구  2024  27285437  20790579
# 4      0    서울특별시  강서구  2024  32728567  29761796
# 5      0    서울특별시  관악구  2024  49710153  36209074
# ..   ...      ...  ...   ...       ...       ...
# 213    0  전북특별자치도  완주군  2024    284374    121900
# 214    0  전북특별자치도  익산시  2024   1398813   1067758
# 215    0  전북특별자치도  임실군  2024        39       244
# 216    0  전북특별자치도  장수군  2024        11        86
# 217    0  전북특별자치도  전주시  2024    564482    141899
#
# [217 rows x 6 columns]

# %%
df7['시군구명'] = df7['시도'].astype(str) + ' ' + df7['시군구'].astype(str)
df7.drop(columns=['시도','시군구'], axis=1, inplace=True)

# %%
standard_codes = pd.read_csv('/content/drive/MyDrive/BDA/data/0 인프라지수 최종 종합/국민여행조사_지역코드.csv')

df7 = df7.merge(
    standard_codes,
    how='left',
    left_on=['시군구명'],
    right_on=['지역명 ']
    )

# 기존 시도코드 컬럼을 새 코드로 대체
df7['시도코드'] = df7['지역 코드']

# 시군구코드 5자리만 남기고 나머지 제거
df7['시도코드'] = df7['시도코드'].astype(str).str[:5]

# 불필요한 컬럼 삭제
df7.drop(columns=['지역명 ', '지역 코드'], axis=1, inplace=True)
df7.dropna(axis=0, inplace=True)

# %%
nan_index = df7[df7['시도코드']=='nan'].index
nan_index
# Out:
# Index([ 41,  54,  75, 190, 191, 192, 193, 194, 195, 196, 197, 198, 199, 200,
#        201, 202, 203, 204, 205, 206, 207, 208, 209, 210, 211, 212, 213, 214,
#        215, 216],
#       dtype='int64')

# %%
nan_index = df7[df7['시도코드']=='nan'].index
df7.loc[nan_index, '시군구명'].value_counts()
# Out:
# 시군구명
# 대구광역시 군위군      1
# 인천광역시 미추홀구     1
# 세종특별자치시 세종시    1
# 강원특별자치도 강릉시    1
# 강원특별자치도 고성군    1
# 강원특별자치도 동해시    1
# 강원특별자치도 삼척시    1
# 강원특별자치도 속초시    1
# 강원특별자치도 양양군    1
# 강원특별자치도 영월군    1
# 강원특별자치도 원주시    1
# 강원특별자치도 인제군    1
# 강원특별자치도 정선군    1
# 강원특별자치도 철원군    1
# 강원특별자치도 춘천시    1
# 강원특별자치도 태백시    1
# 강원특별자치도 평창군    1
# 강원특별자치도 홍천군    1
# 강원특별자치도 화천군    1
# 강원특별자치도 횡성군    1
# 전북특별자치도 군산시    1
# 전북특별자치도 김제시    1
# 전북특별자치도 남원시    1
# 전북특별자치도 무주군    1
# 전북특별자치도 순창군    1
# 전북특별자치도 완주군    1
# 전북특별자치도 익산시    1
# 전북특별자치도 임실군    1
# 전북특별자치도 장수군    1
# 전북특별자치도 전주시    1
# Name: count, dtype: int64

# %%
# 강원특별자치도 -> 강원도 변경, 전북특별자치도 -> 전라북도, 인천광역시 미추홀구 -> 인천광역시 남구 변경
def replace_special_province(address):
    if isinstance(address, str):
        if address.startswith("강원특별자치도"):
            return address.replace("강원특별자치도", "강원도")
        elif address.startswith("전북특별자치도"):
            return address.replace("전북특별자치도", "전라북도")
        elif address.endswith("미추홀구"):
            return address.replace("미추홀구", "남구")
    return address

df7.loc[nan_index, '시군구명'] = df7.loc[nan_index, '시군구명'].apply(replace_special_province)

# 세종특별자치시 세종시 -> 세종특별자치시
df7.loc[nan_index[2], '시군구명'] = " ".join(df7.loc[2, '시군구명'].split()[:-1])

# 대구광역시 군위군 -> 국민여행조사 코드북에 코드가 X
df7.drop(nan_index[0], axis=0, inplace=True)

# %%
nan_index = df7[df7['시도코드']=='nan'].index
df7.loc[nan_index, '시군구명'].value_counts()
# Out:
# 시군구명
# 인천광역시 남구    1
# 서울특별시       1
# 강원도 강릉시     1
# 강원도 고성군     1
# 강원도 동해시     1
# 강원도 삼척시     1
# 강원도 속초시     1
# 강원도 양양군     1
# 강원도 영월군     1
# 강원도 원주시     1
# 강원도 인제군     1
# 강원도 정선군     1
# 강원도 철원군     1
# 강원도 춘천시     1
# 강원도 태백시     1
# 강원도 평창군     1
# 강원도 홍천군     1
# 강원도 화천군     1
# 강원도 횡성군     1
# 전라북도 군산시    1
# 전라북도 김제시    1
# 전라북도 남원시    1
# 전라북도 무주군    1
# 전라북도 순창군    1
# 전라북도 완주군    1
# 전라북도 익산시    1
# 전라북도 임실군    1
# 전라북도 장수군    1
# 전라북도 전주시    1
# Name: count, dtype: int64

# %%
# 법정동 시군구 코드 데이터 불러오기
standard_codes = pd.read_csv('/content/drive/MyDrive/BDA/data/교통 인프라 지표 데이터 (지원)/국토교통부_법정동코드_20240805.csv',encoding='cp949')

df7 = df7.merge(
    standard_codes,
    how='left',
    left_on=['시군구명'],
    right_on=['법정동명']
    )

# 기존 시도코드 컬럼을 새 코드로 대체
df7['시도코드'] = df7['법정동코드']

# 시군구코드 5자리만 남기고 나머지 제거
df7['시도코드'] = df7['시도코드'].astype(str).str[:5]

# 불필요한 컬럼 삭제
df7.drop(columns=['법정동명', '법정동코드', '폐지여부'], axis=1, inplace=True)
df7.dropna(axis=0, inplace=True)

# %%
df7.drop(columns=['년','시군구명'], axis=1, inplace=True)

# %%
df7
# Out:
#       시도코드       발생량       도착량
# 0    11680  60502130  84156330
# 1    11740  17546120  15628516
# 2    11305  27285437  20790579
# 3    11500  32728567  29761796
# 4    11620  49710153  36209074
# ..     ...       ...       ...
# 213  45710    284374    121900
# 214  45140   1398813   1067758
# 215  45750        39       244
# 216  45740        11        86
# 217  45110    564482    141899
#
# [218 rows x 3 columns]

# %%
df7[df7['시도코드']=='nan'].count()
# Out:
# 시도코드    0
# 발생량     0
# 도착량     0
# dtype: int64

# %%
df7.drop(columns=['도착량'], axis=1, inplace=True)

# %%
df7
# Out:
#       시도코드       발생량
# 0    11680  60502130
# 1    11740  17546120
# 2    11305  27285437
# 3    11500  32728567
# 4    11620  49710153
# ..     ...       ...
# 213  45710    284374
# 214  45140   1398813
# 215  45750        39
# 216  45740        11
# 217  45110    564482
#
# [218 rows x 2 columns]

# %%
df7.to_csv('환승통행량_전처리.csv',index=False)

from google.colab import files
files.download('환승통행량_전처리.csv')

# %% [markdown]
# # 이용량 지표(수단통행량)

# %% [markdown]
# ## (2024)

# %%
df10 = pd.read_excel('/content/drive/MyDrive/BDA/data/교통 인프라 지표 데이터 (지원)/이용량 지표(수단 통행량)/이용량 지표(수단통행량)_2024.xlsx')

# %%
df10
# Out:
#     시도코드     시도  시군구     년  교통수단         발생량         도착량
# 0     합계      0    0     0     0  8208731234  7216143382
# 1     11  서울특별시  강남구  2024     ~           0       42352
# 2      0      0    0     0  공항버스      355416           0
# 3      0      0    0     0    광역     6747011     4895620
# 4      0      0    0     0  도시철도   232739220   241315583
# ..   ...    ...  ...   ...   ...         ...         ...
# 687    0      0    0     0    시내       26607         379
# 688    0      0    0     0    좌석    36348431     1487398
# 689    0      0  정읍시  2024    시내       17740       17129
# 690    0      0    0     0    좌석     1849304           0
# 691    0      0  진안군  2024    시내      643899           0
#
# [692 rows x 7 columns]

# %%
df10.drop(0, axis=0, inplace=True)

# %%
code_index1 = df10[df10['시도'] != 0].index
code_index2 = df10[df10['시군구'] != 0].index

# %%
for i in range(len(code_index1)-1):
    start = code_index1[i]
    end = code_index1[i+1]
    df10.loc[start:end-1,'시도'] = df10.loc[start,'시도']

df10.loc[code_index1[-1]:,'시도'] = df10.loc[code_index1[-1],'시도']

# %%
for i in range(len(code_index2)-1):
    start = code_index2[i]
    end = code_index2[i+1]
    df10.loc[start:end-1,'시군구'] = df10.loc[start,'시군구']

df10.loc[code_index2[-1]:,'시군구'] = df10.loc[code_index2[-1],'시군구']

# %%
df10
# Out:
#     시도코드       시도  시군구     년  교통수단        발생량        도착량
# 1     11    서울특별시  강남구  2024     ~          0      42352
# 2      0    서울특별시  강남구     0  공항버스     355416          0
# 3      0    서울특별시  강남구     0    광역    6747011    4895620
# 4      0    서울특별시  강남구     0  도시철도  232739220  241315583
# 5      0    서울특별시  강남구     0    마을   13974124   13327810
# ..   ...      ...  ...   ...   ...        ...        ...
# 687    0  전북특별자치도  전주시     0    시내      26607        379
# 688    0  전북특별자치도  전주시     0    좌석   36348431    1487398
# 689    0  전북특별자치도  정읍시  2024    시내      17740      17129
# 690    0  전북특별자치도  정읍시     0    좌석    1849304          0
# 691    0  전북특별자치도  진안군  2024    시내     643899          0
#
# [691 rows x 7 columns]

# %%
df10['시군구명'] = df10['시도'].astype(str) + ' ' + df10['시군구'].astype(str)
df10.drop(columns=['시도','시군구'], axis=1, inplace=True)

# %%
# 법정동 시군구 코드 데이터 불러오기
standard_codes = pd.read_csv('/content/drive/MyDrive/BDA/data/교통 인프라 지표 데이터 (지원)/국토교통부_법정동코드_20240805.csv',encoding='cp949')

df10 = df10.merge(
    standard_codes,
    how='left',
    left_on=['시군구명'],
    right_on=['법정동명']
    )

# 기존 시도코드 컬럼을 새 코드로 대체
df10['시도코드'] = df10['법정동코드']

# 시군구코드 5자리만 남기고 나머지 제거
df10['시도코드'] = df10['시도코드'].astype(str).str[:5]

# 불필요한 컬럼 삭제
df10.drop(columns=['법정동명', '법정동코드', '폐지여부'], axis=1, inplace=True)
df10.dropna(axis=0, inplace=True)

# %%
nan_index = df10[df10['시도코드']=='nan'].index
nan_index
# Out:
# Index([303, 304], dtype='int64')

# %%
df10.loc[nan_index,'시군구명'] = df10.loc[nan_index, '시군구명'].str.split().str[0]

# %%
# 법정동 시군구 코드 데이터 불러오기
standard_codes = pd.read_csv('/content/drive/MyDrive/BDA/data/교통 인프라 지표 데이터 (지원)/국토교통부_법정동코드_20240805.csv',encoding='cp949')

df10 = df10.merge(
    standard_codes,
    how='left',
    left_on=['시군구명'],
    right_on=['법정동명']
    )

# 기존 시도코드 컬럼을 새 코드로 대체
df10['시도코드'] = df10['법정동코드']

# 시군구코드 5자리만 남기고 나머지 제거
df10['시도코드'] = df10['시도코드'].astype(str).str[:5]

# 불필요한 컬럼 삭제
df10.drop(columns=['법정동명', '법정동코드', '폐지여부'], axis=1, inplace=True)
df10.dropna(axis=0, inplace=True)

# %%
df10.drop(columns=['년','시군구명'], axis=1, inplace=True)

# %%
df10
# Out:
#       시도코드  교통수단        발생량        도착량
# 0    11680     ~          0      42352
# 1    11680  공항버스     355416          0
# 2    11680    광역    6747011    4895620
# 3    11680  도시철도  232739220  241315583
# 4    11680    마을   13974124   13327810
# ..     ...   ...        ...        ...
# 710  52110    시내      26607        379
# 711  52110    좌석   36348431    1487398
# 712  52180    시내      17740      17129
# 713  52180    좌석    1849304          0
# 714  52720    시내     643899          0
#
# [715 rows x 4 columns]

# %%
df10[df10['시도코드']=='nan'].count()
# Out:
# 시도코드    0
# 발생량     0
# 도착량     0
# dtype: int64

# %%
df10 = df10.groupby('시도코드')[['발생량', '도착량']].sum().reset_index()

# %%
df10
# Out:
#       시도코드        발생량        도착량
# 0    11110  182596381  180962251
# 1    11140  213169502  208089840
# 2    11170  123089783  127372845
# 3    11200  103408307  104370398
# 4    11215  113293376  112227010
# ..     ...        ...        ...
# 237  52740       7149        554
# 238  52750     233023       5061
# 239  52770     269246         69
# 240  52790       8033          0
# 241  52800     385375          0
#
# [242 rows x 3 columns]

# %%
df10.to_csv('수단통행량_2024_전처리.csv',index=False)

from google.colab import files
files.download('수단통행량_2024_전처리.csv')
